# %% [markdown]
# <a href="https://colab.research.google.com/github/wsandy1/aero-jupyter-notebooks/blob/main/SESA2022%20Tutorial%20Sheet%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

x_min = -5
x_max = 5
y_min = -5
y_max = 5

dx = 0.1
dy = 0.1

Gamma = 5
R = 2

xa = np.arange(x_min, x_max+dx, dx)
ya = np.arange(y_min, y_max+dy, dy)

x,y = np.meshgrid(xa, ya)

r = np.sqrt(x**2 + y**2)
theta = np.arctan2(y, x)

u_theta = np.where(r < R, (Gamma*r)/R**2, Gamma/r)

u = -u_theta*np.sin(theta)
v = u_theta*np.cos(theta)

plt.figure(figsize=(12,10), dpi=100)
plt.contourf(x,y,u_theta, 100)
plt.colorbar()
plt.quiver(x,y,u,v,)

theta_circle = np.linspace(0, 2*np.pi, 100)
x_circle = R*np.cos(theta_circle)
y_circle = R*np.sin(theta_circle)

plt.plot(x_circle, y_circle, "r-")

plt.show()
